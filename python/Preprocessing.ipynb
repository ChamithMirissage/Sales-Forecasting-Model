# %%
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
d1 = pd.read_excel("2013Jan_2013Jun.xlsx")
d1.to_pickle("./1st_6months.pkl")

# %%
first = pd.read_pickle("./1st_6months.pkl")
print (first)
first = first.filter(['CDateTime','SalesPoint','SalesChannelKey','GroupCat','ItemSize','DiscountPcnt','QTY'], axis=1)
print (first)
# Out:
#         AutoNo  ItemKey  LocationKEY  GeographyKey  InvDateKey  \
# 0       193926     4652          171            78    20130101
# 1       193927    65556          154            56    20130101
# 2       193928    66266          154            56    20130101
# 3       193929    14589          129            63    20130101
# 4       193930    15110          129            63    20130101
# 5       193931    63768          137            78    20130101
# 6       193932    72390          137            78    20130101
# 7       193933    74121          360            65    20130101
# 8       193934    61961          370            65    20130101
# 9       193935    63813          172            78    20130101
# 10      193936    62798          195            54    20130101
# 11      193937     4670          194            54    20130101
# 12      193938     5420          362            65    20130101
# 13      193939     6288          367            65    20130101
# ...

# %%
d2 = pd.read_excel("2013Jul_2013Dec.xlsx")
d2.to_pickle("./2nd_6months.pkl")

# %%
second = pd.read_pickle("./2nd_6months.pkl")
second = second.filter(['CDateTime','SalesPoint','SalesChannelKey','GroupCat','ItemSize','DiscountPcnt','QTY'], axis=1)
#second['QTY'] = second['QTY'].astype(int)
print (second)
# Out:
#         CDateTime SalesPoint  SalesChannelKey         GroupCat ItemSize  \
# 0      2013-07-01      LWSR                 7       WALL TILES        T
# 1      2013-07-01      LWSR                 7       WALL TILES        V
# 2      2013-07-01      LWSR                 4       WALL TILES        P
# 3      2013-07-01      LWSR                 4       WALL TILES        P
# 4      2013-07-01      LWSR                 4       WALL TILES        P
# 5      2013-07-01      FDNIT                5      FLOOR TILES        A
# 6      2013-07-01      FDPER                5  SWISSTEK ALUMIN        T
# 7      2013-07-01      FDPER                5            GROUT        Q
# 8      2013-07-01      FDALU                5       WALL TILES        T
# 9      2013-07-01      LWSR                 7            GROUT        Q
# 10     2013-07-01      LWSR                 4            GROUT        Q
# 11     2013-07-01      CABLM                1      FLOOR TILES        M
# ...

# %%
d3 = pd.read_excel("2014Jan_2014Jun.xlsx")
d3.to_pickle("./3rd_6months.pkl")

# %%
third = pd.read_pickle("./3rd_6months.pkl")
third = third.filter(['CDateTime','SalesPoint','SalesChannelKey','GroupCat','ItemSize','DiscountPcnt','QTY'], axis=1)
print (third)
# Out:
#         CDateTime SalesPoint  SalesChannelKey         GroupCat ItemSize  \
# 0      2014-01-01      FDMIN                5       WALL TILES        S
# 1      2014-01-01      FDMIN                5       WALL TILES        P
# 2      2014-01-01      DELUN                2      FLOOR TILES        A
# 3      2014-01-01      DELUN                2      FLOOR TILES        M
# 4      2014-01-01      LWSR                 4       WALL TILES        D
# 5      2014-01-01      LWSR                 4       WALL TILES        D
# 6      2014-01-01      LWSR                 4       WALL TILES        V
# 7      2014-01-01      DELUN                2       WALL TILES        D
# 8      2014-01-01      DELUN                2       WALL TILES        P
# 9      2014-01-01      FDGAL                5       WALL TILES        D
# 10     2014-01-01      FDGAL                5       WALL TILES        D
# 11     2014-01-01      FDVAV                5       WALL TILES        V
# ...

# %%
d4 = pd.read_excel("2014Jul_2014Dec.xlsx")
d4.to_pickle("./4th_6months.pkl")

# %%
forth = pd.read_pickle("./4th_6months.pkl")
forth = forth.filter(['CDateTime','SalesPoint','SalesChannelKey','GroupCat','ItemSize','DiscountPcnt','QTY'], axis=1)
print (forth)
# Out:
#         CDateTime SalesPoint  SalesChannelKey         GroupCat ItemSize  \
# 0      2014-07-01      LWSR                 4       WALL TILES        R
# 1      2014-07-01      LWSR                 4       WALL TILES        R
# 2      2014-07-01      LWSR                 4  OTHER IMPORTED         D
# 3      2014-07-01      LWSR                 4      FLOOR TILES        M
# 4      2014-07-01      LWSR                 4      FLOOR TILES        A
# 5      2014-07-01      LWSR                 4            GROUT        Q
# 6      2014-07-01      CAGOG                1       WALL TILES        F
# 7      2014-07-01      CAGOG                1       WALL TILES        F
# 8      2014-07-01      LWSR                 7       WALL TILES        D
# 9      2014-07-01      LWSR                 4       WALL TILES        R
# 10     2014-07-01      CAGOG                1       WALL TILES        D
# 11     2014-07-01      CAGOG                1       WALL TILES        V
# ...

# %%
d5 = pd.read_excel("2015Jan_2015Jun.xlsx")
d5.to_pickle("./5th_6months.pkl")

# %%
fifth = pd.read_pickle("./5th_6months.pkl")
fifth = fifth.filter(['CDateTime','SalesPoint','SalesChannelKey','GroupCat','ItemSize','DiscountPcnt','QTY'], axis=1)
print (fifth)
# Out:
#         CDateTime SalesPoint  SalesChannelKey         GroupCat ItemSize  \
# 0      2015-01-01      LWSR                 4       WALL TILES        P
# 1      2015-01-01      LWSR                 4      FLOOR TILES        L
# 2      2015-01-01      LWSR                 4            GROUT        Q
# 3      2015-01-01      LWSR                 4            GROUT        Q
# 4      2015-01-01      LWSR                 4            GROUT        Q
# 5      2015-01-01      DELUN                2       WALL TILES        V
# 6      2015-01-01      FDAMT                5           MORTAR        P
# 7      2015-01-01      KDSR                 5      FLOOR TILES        L
# 8      2015-01-01      KDSR                 5      FLOOR TILES        M
# 9      2015-01-01      FDKEG                5       WALL TILES        R
# 10     2015-01-01      CAKAN                1       WALL TILES        G
# 11     2015-01-01      CAKAN                1       WALL TILES        D
# ...

# %%
d6 = pd.read_excel("2015Jul_2015Dec.xlsx")
d6.to_pickle("./6th_6months.pkl")

# %%
sixth = pd.read_pickle("./6th_6months.pkl")
sixth = sixth.filter(['CDateTime','SalesPoint','SalesChannelKey','GroupCat','ItemSize','DiscountPcnt','QTY'], axis=1)
print (sixth)
# Out:
#         CDateTime SalesPoint  SalesChannelKey         GroupCat ItemSize  \
# 0      2015-07-01      FDJAF                5       WALL TILES        P
# 1      2015-07-01      FDVAV                5            GROUT        Q
# 2      2015-07-01      FDVAV                5  SWISSTEK ALUMIN        T
# 3      2015-07-01      FDVAV                5      FLOOR TILES        U
# 4      2015-07-01      FDJAF                5       WALL TILES        P
# 5      2015-07-01      FDJAF                5      FLOOR TILES        A
# 6      2015-07-01      FDJAF                5       WALL TILES        A
# 7      2015-07-01      FDJAF                5       WALL TILES        P
# 8      2015-07-01      FDJAF                5       WALL TILES        A
# 9      2015-07-01      FDJAF                5      FLOOR TILES        M
# 10     2015-07-01      FDJAF                5            GROUT        Q
# 11     2015-07-01      FDJAF                5  DECORATIVE PEBB        P
# ...

# %%
d7 = pd.read_excel("2016Jan_2016Jun.xlsx")
d7.to_pickle("./7th_6months.pkl")

# %%
seventh = pd.read_pickle("./7th_6months.pkl")
seventh = seventh.filter(['CDateTime','SalesPoint','SalesChannelKey','GroupCat','ItemSize','DiscountPcnt','QTY'], axis=1)
print (seventh)
# Out:
#         CDateTime SalesPoint  SalesChannelKey         GroupCat ItemSize  \
# 0      2016-01-01      DBDIG                2       WALL TILES        D
# 1      2016-01-01      DBDIG                2       WALL TILES        D
# 2      2016-01-01      FDWAR                5      FLOOR TILES        U
# 3      2016-01-01      DELUN                2      FLOOR TILES        T
# 4      2016-01-01      DELUN                2      FLOOR TILES        T
# 5      2016-01-01      DELUN                3      FLOOR TILES        T
# 6      2016-01-01      DELUN                3      FLOOR TILES        T
# 7      2016-01-01      DELUN                3      FLOOR TILES        M
# 8      2016-01-01      FDWEL                5      FLOOR TILES        U
# 9      2016-01-01      FDWEL                5      FLOOR TILES        U
# 10     2016-01-01      FDWEL                5      FLOOR TILES        U
# 11     2016-01-01      FDWEL                5      FLOOR TILES        U
# ...

# %%
d8 = pd.read_excel("2016Jul_2016Dec.xlsx")
d8.to_pickle("./8th_6months.pkl")

# %%
eighth = pd.read_pickle("./8th_6months.pkl")
eighth = eighth.filter(['CDateTime','SalesPoint','SalesChannelKey','GroupCat','ItemSize','DiscountPcnt','QTY'], axis=1)
print (eighth)
# Out:
#         CDateTime SalesPoint  SalesChannelKey         GroupCat ItemSize  \
# 0      2016-07-01      FDKDW                5       WALL TILES        P
# 1      2016-07-01      FDVAV                5            GROUT        Q
# 2      2016-07-01      FDVAV                5            GROUT        Q
# 3      2016-07-01      FDVAV                5            GROUT        Q
# 4      2016-07-01      FDVAV                5      FLOOR TILES        M
# 5      2016-07-01      DBMAT                2      FLOOR TILES        T
# 6      2016-07-01      JWSR                 4      FLOOR TILES        X
# 7      2016-07-01      JWSR                 4      FLOOR TILES        X
# 8      2016-07-01      JWSR                 4      FLOOR TILES        A
# 9      2016-07-01      FDKAL                5       WALL TILES        A
# 10     2016-07-01      FDJEL                5       WALL TILES        D
# 11     2016-07-01      CABLM                1       WALL TILES        P
# ...

# %%
d9 = pd.read_excel("2017Jan_2017Jun.xlsx")
d9.to_pickle("./9th_6months.pkl")

# %%
ninth = pd.read_pickle("./9th_6months.pkl")
ninth = ninth.filter(['CDateTime','SalesPoint','SalesChannelKey','GroupCat','ItemSize','DiscountPcnt','QTY'], axis=1)
print (ninth)
# Out:
#         CDateTime SalesPoint  SalesChannelKey         GroupCat ItemSize  \
# 0      2017-01-01      FDBDU                5      FLOOR TILES        Y
# 1      2017-01-01      FDBDU                5      FLOOR TILES        Y
# 2      2017-01-01      FDBDU                5      FLOOR TILES        U
# 3      2017-01-01      FDBA1                5      FLOOR TILES        T
# 4      2017-01-01      CADAM                1       WALL TILES        D
# 5      2017-01-01      CADAM                1       WALL TILES        D
# 6      2017-01-01      CADAM                1       WALL TILES        D
# 7      2017-01-01      CADAM                1       WALL TILES        D
# 8      2017-01-01      CADAM                1       WALL TILES        D
# 9      2017-01-01      CADAM                1       WALL TILES        D
# 10     2017-01-01      FDGAL                5      FLOOR TILES        Y
# 11     2017-01-01      FDEMB                5            GROUT        Q
# ...

# %%
d10 = pd.read_excel("2017Jul_2017Dec.xlsx")
d10.to_pickle("./10th_6months.pkl")

# %%
tenth = pd.read_pickle("./10th_6months.pkl")
tenth = tenth.filter(['CDateTime','SalesPoint','SalesChannelKey','GroupCat','ItemSize','DiscountPcnt','QTY'], axis=1)
print (tenth)
# Out:
#         CDateTime SalesPoint  SalesChannelKey         GroupCat ItemSize  \
# 0      2017-07-01      CABLM                1            GROUT        Q
# 1      2017-07-01      LWSR                 4       WALL TILES        P
# 2      2017-07-01      DBNAW                2     INDIAN TILES        D
# 3      2017-07-01      DBNAW                2      FLOOR TILES        T
# 4      2017-07-01      DBNAW                2      FLOOR TILES        T
# 5      2017-07-01      LWSR                 4       WALL TILES        P
# 6      2017-07-01      LWSR                 4       WALL TILES        P
# 7      2017-07-01      LWSR                 4       WALL TILES        A
# 8      2017-07-01      LWSR                 4       WALL TILES        D
# 9      2017-07-01      FDMOT                5      FLOOR TILES        T
# 10     2017-07-01      FDWEN                5      FLOOR TILES        T
# 11     2017-07-01      LWSR                 4       WALL TILES        A
# ...

# %%
d11 = pd.read_excel("2018Jan_2018Jun.xlsx")
d11.to_pickle("./11th_6months.pkl")

# %%
eleventh = pd.read_pickle("./11th_6months.pkl")
eleventh = eleventh.filter(['CDateTime','SalesPoint','SalesChannelKey','GroupCat','ItemSize','DiscountPcnt','QTY'], axis=1)
print (eleventh)
# Out:
#         CDateTime SalesPoint  SalesChannelKey      GroupCat ItemSize  \
# 0      2018-01-01      FDEMB                5   FLOOR TILES        Y
# 1      2018-01-01      FDEMB                5  INDIAN TILES        D
# 2      2018-01-01      FDBDU                5   FLOOR TILES        T
# 3      2018-01-01      FDWEL                5        MORTAR        P
# 4      2018-01-01      FDWEL                5        MORTAR        P
# 5      2018-01-01      FDMON                5   ACCESSORIES        P
# 6      2018-01-01      FDRAT                5   FLOOR TILES        T
# 7      2018-01-01      FDRAT                5         GROUT        Q
# 8      2018-01-01      FDRAT                5         GROUT        Q
# 9      2018-01-01      FDBA1                5   FLOOR TILES        T
# 10     2018-01-01      FDBA1                5         GROUT        Q
# 11     2018-01-01      FDBA1                5         GROUT        Q
# 12     2018-01-01      FDMON                5   FLOOR TILES        A
# ...

# %%
d12 = pd.read_excel("2018Jul_2018Dec.xlsx")
d12.to_pickle("./12th_6months.pkl")

# %%
twelveth = pd.read_pickle("./12th_6months.pkl")
twelveth = twelveth.filter(['CDateTime','SalesPoint','SalesChannelKey','GroupCat','ItemSize','DiscountPcnt','QTY'], axis=1)
print (twelveth)
# Out:
#         CDateTime SalesPoint  SalesChannelKey         GroupCat ItemSize  \
# 0      2018-07-01      FDGAL                5            GROUT        Q
# 1      2018-07-01      DBKIR                2      FLOOR TILES        T
# 2      2018-07-01      DBKIR                2      FLOOR TILES        T
# 3      2018-07-01      FDAMP                5           MORTAR        P
# 4      2018-07-01      FDBDU                5     INDIAN TILES        D
# 5      2018-07-01      FDBDU                5            GROUT        Q
# 6      2018-07-01      FDMON                5       WALL TILES        P
# 7      2018-07-01      FDMON                5       WALL TILES        P
# 8      2018-07-01      FDMON                5       WALL TILES        P
# 9      2018-07-01      FDKAN                5      FLOOR TILES        T
# 10     2018-07-01      CADAM                1       WALL TILES        F
# 11     2018-07-01      CADAM                1       WALL TILES        F
# ...

# %%
#dataset1 = pd.concat([first, second], sort=False)

# %%
#dataset1 = pd.concat([dataset1, third], sort=False)

# %%
#dataset1 = pd.concat([dataset1, forth], sort=False)

# %%
#dataset1 = pd.concat([dataset1, fifth], sort=False)

# %%
dataset1 = pd.concat([dataset1, sixth], sort=False)

# %%
dataset2 = pd.concat([seventh, eighth], sort=False)

# %%
dataset2 = pd.concat([dataset2, ninth], sort=False)

# %%
dataset2 = pd.concat([dataset2, tenth], sort=False)

# %%
dataset2 = pd.concat([dataset2, eleventh], sort=False)

# %%
dataset2 = pd.concat([dataset2, twelveth], sort=False)

# %%
print (dataset1)
# Out:
#         CDateTime SalesPoint  SalesChannelKey     GroupCat ItemSize  \
# 0      2013-01-01      FDHOR                5  FLOOR TILES        A
# 1      2013-01-01      FDKEG                5   WALL TILES        G
# 2      2013-01-01      FDKEG                5   WALL TILES        G
# 3      2013-01-01      FDNIT                5  FLOOR TILES        M
# 4      2013-01-01      FDNIT                5  FLOOR TILES        P
# ...           ...        ...              ...          ...      ...
# 383614 2015-12-31      FDBAL                5  FLOOR TILES        U
# 383615 2015-12-31      FDALU                5   WALL TILES        P
# 383616 2015-12-31      DBNUG                2   WALL TILES        F
# 383617 2015-12-31      DBNUG                2   WALL TILES        F
# 383618 2015-12-31      DBNUG                2   WALL TILES        F
#
#         DiscountPcnt    QTY
# 0               10.0   14.0
# 1               25.0    1.0
# 2               25.0    6.0
# 3               25.0    1.0
# ...

# %%
print (dataset2)
# Out:
#         CDateTime SalesPoint  SalesChannelKey     GroupCat ItemSize  \
# 0      2016-01-01      DBDIG                2   WALL TILES        D
# 1      2016-01-01      DBDIG                2   WALL TILES        D
# 2      2016-01-01      FDWAR                5  FLOOR TILES        U
# 3      2016-01-01      DELUN                2  FLOOR TILES        T
# 4      2016-01-01      DELUN                2  FLOOR TILES        T
# ...           ...        ...              ...          ...      ...
# 445583 2018-12-31      DELUN                3   WALL TILES        P
# 445584 2018-12-31      DELUN                3   WALL TILES        P
# 445585 2018-12-31      FDBA1                5  FLOOR TILES        T
# 445586 2018-12-31      FDBA1                5  FLOOR TILES        T
# 445587 2018-12-31      FDJEL                5        GROUT        Q
#
#         DiscountPcnt   QTY
# 0                0.0   660
# 1                0.0   308
# 2                0.0     4
# 3                0.0  1056
# ...

# %%
print (len(first)+len(second)+len(third)+len(forth)+len(fifth)+len(sixth))
# Out:
# 1864968

# %%
print (len(dataset1))
# Out:
# 1864968

# %%
print (len(seventh)+len(eighth)+len(ninth)+len(tenth)+len(eleventh)+len(twelveth))
# Out:
# 2105093

# %%
print (len(dataset2))
# Out:
# 2105093

# %%
dataset = pd.concat([dataset1, dataset2], sort=False)

# %%
print (dataset)
# Out:
#         CDateTime SalesPoint  SalesChannelKey     GroupCat ItemSize  \
# 0      2013-01-01      FDHOR                5  FLOOR TILES        A
# 1      2013-01-01      FDKEG                5   WALL TILES        G
# 2      2013-01-01      FDKEG                5   WALL TILES        G
# 3      2013-01-01      FDNIT                5  FLOOR TILES        M
# 4      2013-01-01      FDNIT                5  FLOOR TILES        P
# ...           ...        ...              ...          ...      ...
# 445583 2018-12-31      DELUN                3   WALL TILES        P
# 445584 2018-12-31      DELUN                3   WALL TILES        P
# 445585 2018-12-31      FDBA1                5  FLOOR TILES        T
# 445586 2018-12-31      FDBA1                5  FLOOR TILES        T
# 445587 2018-12-31      FDJEL                5        GROUT        Q
#
#         DiscountPcnt    QTY
# 0               10.0   14.0
# 1               25.0    1.0
# 2               25.0    6.0
# 3               25.0    1.0
# ...

# %%
print (len(dataset))
# Out:
# 3970061

# %%
print (len(first)+len(second)+len(third)+len(forth)+len(fifth)+len(sixth)+len(seventh)+len(eighth)+len(ninth)+len(tenth)+len(eleventh)+len(twelveth))
# Out:
# 3970061

# %%
dataset.to_pickle("./6years.pkl")

# %%
dataset = pd.read_pickle("./6years.pkl")
print (dataset)
# Out:
#         CDateTime SalesPoint  SalesChannelKey         GroupCat ItemSize  \
# 0      2013-01-01      FDHOR                5      FLOOR TILES        A
# 1      2013-01-01      FDKEG                5       WALL TILES        G
# 2      2013-01-01      FDKEG                5       WALL TILES        G
# 3      2013-01-01      FDNIT                5      FLOOR TILES        M
# 4      2013-01-01      FDNIT                5      FLOOR TILES        P
# 5      2013-01-01      FDPND                5       WALL TILES        D
# 6      2013-01-01      FDPND                5       WALL TILES        S
# 7      2013-01-01      LWSR                 4       WALL TILES        T
# 8      2013-01-01      LWSR                 4       WALL TILES        D
# 9      2013-01-01      FDHOR                5       WALL TILES        D
# 10     2013-01-01      KDSR                 5       WALL TILES        D
# 11     2013-01-01      KDSR                 5      FLOOR TILES        A
# ...

# %%
dataset['DiscountPcnt'].describe().apply(lambda x: format(x, 'f'))
# Out:
# count    3957580.000000
# mean           6.754360
# std           15.927278
# min          -35.000000
# 25%            0.000000
# 50%            0.000000
# 75%            6.000000
# max          100.000000
# Name: DiscountPcnt, dtype: object

# %%
df.apply(lambda x: '%.5f' % x, axis=1)

# %%
dataset['QTY'].describe().apply(lambda x: '%.3f' % x)
# Out:
# count    3970061.000
# mean         162.571
# std          701.068
# min            1.000
# 25%            2.000
# 50%           20.000
# 75%          100.000
# max       165088.000
# Name: QTY, dtype: object

# %%
fouryears = pd.concat([fifth, sixth], sort=False)

# %%
fouryears = pd.concat([fouryears, seventh], sort=False)

# %%
fouryears = pd.concat([fouryears, eighth], sort=False)

# %%
fouryears = pd.concat([fouryears, ninth], sort=False)

# %%
fouryears = pd.concat([fouryears, tenth], sort=False)

# %%
fouryears = pd.concat([fouryears, eleventh], sort=False)

# %%
fouryears = pd.concat([fouryears, twelveth], sort=False)

# %%
print (fouryears)
# Out:
#         CDateTime SalesPoint  SalesChannelKey         GroupCat ItemSize  \
# 0      2015-01-01      LWSR                 4       WALL TILES        P
# 1      2015-01-01      LWSR                 4      FLOOR TILES        L
# 2      2015-01-01      LWSR                 4            GROUT        Q
# 3      2015-01-01      LWSR                 4            GROUT        Q
# 4      2015-01-01      LWSR                 4            GROUT        Q
# 5      2015-01-01      DELUN                2       WALL TILES        V
# 6      2015-01-01      FDAMT                5           MORTAR        P
# 7      2015-01-01      KDSR                 5      FLOOR TILES        L
# 8      2015-01-01      KDSR                 5      FLOOR TILES        M
# 9      2015-01-01      FDKEG                5       WALL TILES        R
# 10     2015-01-01      CAKAN                1       WALL TILES        G
# 11     2015-01-01      CAKAN                1       WALL TILES        D
# ...

# %%
fouryears.to_pickle("./4years.pkl")

# %%
fouryears1 = pd.read_pickle("./4years.pkl")
print (fouryears1)
# Out:
#         CDateTime SalesPoint  SalesChannelKey         GroupCat ItemSize  \
# 0      2015-01-01      LWSR                 4       WALL TILES        P
# 1      2015-01-01      LWSR                 4      FLOOR TILES        L
# 2      2015-01-01      LWSR                 4            GROUT        Q
# 3      2015-01-01      LWSR                 4            GROUT        Q
# 4      2015-01-01      LWSR                 4            GROUT        Q
# 5      2015-01-01      DELUN                2       WALL TILES        V
# 6      2015-01-01      FDAMT                5           MORTAR        P
# 7      2015-01-01      KDSR                 5      FLOOR TILES        L
# 8      2015-01-01      KDSR                 5      FLOOR TILES        M
# 9      2015-01-01      FDKEG                5       WALL TILES        R
# 10     2015-01-01      CAKAN                1       WALL TILES        G
# 11     2015-01-01      CAKAN                1       WALL TILES        D
# ...
